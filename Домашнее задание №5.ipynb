# %% [markdown]
# # Домашнее задание  № 5. Матричные разложения/Тематическое моделирование

# %% [markdown]
# ### Задание № 1 (4 балла)

# %%
import gensim
import pandas as pd
import numpy as np
from pymorphy2 import MorphAnalyzer
from collections import Counter
from string import punctuation
from razdel import tokenize as razdel_tokenize
from IPython.display import Image
from IPython.core.display import HTML 
from sklearn.decomposition import TruncatedSVD, NMF, PCA, LatentDirichletAllocation
from sklearn.manifold import TSNE
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer, TfidfTransformer
from sklearn.metrics.pairwise import cosine_distances
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.pipeline import Pipeline
from sklearn.model_selection import KFold, StratifiedKFold
import warnings
from matplotlib import pyplot as plt
import seaborn as sns
morph = MorphAnalyzer()
warnings.filterwarnings("ignore")

# %%
# добавим лемматизацию
def normalize(text):
    normalized_text = [word.text.strip(punctuation) for word \
                                                            in razdel_tokenize(text)]
    normalized_text = [word.lower() for word in normalized_text if word and len(word) < 20 ]
    normalized_text = [morph.parse(word)[0].normal_form for word in normalized_text]
    return ' '.join(normalized_text)

# %%
data = pd.read_csv('avito_category_classification.csv')

# %%
data['description_norm'] = data['description'].apply(normalize)

# %%
vectorizer = CountVectorizer(min_df=5, max_df=0.5)

# %%
def eval_table(X, y, pipeline, N=6):
    # зафиксируем порядок классов
    labels = list(set(y))
    
    # метрики отдельных фолдов будет хранить в табличке
    fold_metrics = pd.DataFrame(index=labels)
    # дополнительно также соберем таблицу ошибок
    errors = np.zeros((len(labels), len(labels)))
    
    # создаем стратегию кросс-валидации
    # shuffle=True (перемешивание) - часто критично важно указать
    # т.к. данные могут быть упорядочены и модель на этом обучится
    kfold = StratifiedKFold(n_splits=N, shuffle=True, )
    
    for i, (train_index, test_index) in enumerate(kfold.split(X, y)):
        # fit-predict как и раньше, но сразу пайплайном
        pipeline.fit(X[train_index], y[train_index])
        preds = pipeline.predict(X[test_index])
        
        # записываем метрику и индекс фолда
        fold_metrics[f'precision_{i}'] = precision_score(y[test_index], preds, labels=labels, average=None)
        fold_metrics[f'recall_{i}'] = recall_score(y[test_index], preds, labels=labels, average=None)
        fold_metrics[f'f1_{i}'] = f1_score(y[test_index], preds, labels=labels, average=None)
        errors += confusion_matrix(y[test_index], preds, labels=labels, normalize='true')
    
    # таблица для усредненных значений
    # тут мы берем колонки со значениями и усредняем их
    # часто также все метрики сразу суммируют и в конце просто делят на количество фолдов
    # но мы тут помимо среднего также хотим посмотреть на стандартное отклонение
    # чтобы понять как сильно варьируются оценки моделей
    result = pd.DataFrame(index=labels)
    result['precision'] = fold_metrics[[f'precision_{i}' for i in range(N)]].mean(axis=1).round(2)
    result['precision_std'] = fold_metrics[[f'precision_{i}' for i in range(N)]].std(axis=1).round(2)
    
    result['recall'] = fold_metrics[[f'recall_{i}' for i in range(N)]].mean(axis=1).round(2)
    result['recall_std'] = fold_metrics[[f'recall_{i}' for i in range(N)]].std(axis=1).round(2)
    
    result['f1'] = fold_metrics[[f'f1_{i}' for i in range(N)]].mean(axis=1).round(2)
    result['f1_std'] = fold_metrics[[f'f1_{i}' for i in range(N)]].std(axis=1).round(2)
    
    # добавим одну колонку со средним по всем классам
    result.loc['mean'] = result.mean().round(2)
    # проценты ошибок просто усредняем
    errors /= N
    
    return result, errors

# %% [markdown]
# __SGDClassifier__

# %%
# NMF
sgdc_nmf = Pipeline([
    ('bow', vectorizer),
    ('scaler', StandardScaler(with_mean=False)),
    ('svd', NMF(60)),
    ('clf', SGDClassifier(max_iter=1000, tol=1e-3))
])

# %%
metrics_sgdc_nmf, errors_sgdc_nmf = eval_table(data['description_norm'], data['category_name'], sgdc_nmf)
metrics_sgdc_nmf
# Out:
#                             precision  precision_std  recall  recall_std  \
# Предложение услуг                0.71           0.06    0.61        0.07
# Ремонт и строительство           0.61           0.13    0.30        0.06
# Автомобили                       0.79           0.11    0.82        0.04
# Бытовая техника                  0.66           0.15    0.17        0.05
# Телефоны                         0.73           0.10    0.60        0.15
# Товары для детей и игрушки       0.58           0.18    0.60        0.11
# Детская одежда и обувь           0.54           0.08    0.49        0.33
# Квартиры                         0.82           0.06    0.92        0.05
# Мебель и интерьер                0.37           0.17    0.36        0.22
# Одежда, обувь, аксессуары        0.54           0.08    0.50        0.26
# mean                             0.64           0.11    0.54        0.13
#
#                               f1  f1_std
# Предложение услуг           0.65    0.05
# Ремонт и строительство      0.39    0.04
# Автомобили                  0.80    0.04
# Бытовая техника             0.26    0.06
# Телефоны                    0.64    0.08
# Товары для детей и игрушки  0.56    0.07
# Детская одежда и обувь      0.45    0.15
# Квартиры                    0.87    0.04
# Мебель и интерьер           0.30    0.07
# Одежда, обувь, аксессуары   0.47    0.11
# mean                        0.54    0.07

# %%
# SVD
sgdc_svd = Pipeline([
    ('bow', vectorizer),
    ('scaler', StandardScaler(with_mean=False)),
    ('svd', TruncatedSVD(500)),
    ('clf', SGDClassifier(max_iter=1000, tol=1e-3))
])

# %%
metrics_sgdc_svd, errors_sgdc_svd = eval_table(data['description_norm'], data['category_name'], sgdc_svd)
metrics_sgdc_svd
# Out:
#                             precision  precision_std  recall  recall_std  \
# Предложение услуг                0.79           0.05    0.70        0.02
# Ремонт и строительство           0.60           0.05    0.51        0.07
# Автомобили                       0.79           0.05    0.87        0.03
# Бытовая техника                  0.68           0.08    0.50        0.03
# Телефоны                         0.83           0.07    0.77        0.03
# Товары для детей и игрушки       0.71           0.03    0.68        0.07
# Детская одежда и обувь           0.71           0.02    0.81        0.03
# Квартиры                         0.96           0.02    0.91        0.02
# Мебель и интерьер                0.70           0.07    0.57        0.05
# Одежда, обувь, аксессуары        0.72           0.03    0.73        0.03
# mean                             0.75           0.05    0.70        0.04
#
#                               f1  f1_std
# Предложение услуг           0.74    0.02
# Ремонт и строительство      0.55    0.06
# Автомобили                  0.82    0.02
# Бытовая техника             0.57    0.05
# Телефоны                    0.79    0.04
# Товары для детей и игрушки  0.69    0.04
# Детская одежда и обувь      0.76    0.02
# Квартиры                    0.93    0.01
# Мебель и интерьер           0.63    0.03
# Одежда, обувь, аксессуары   0.72    0.01
# mean                        0.72    0.03

# %% [markdown]
# __KNeighborsClassifier__

# %%
# NMF
knc_nmf = Pipeline([
    ('bow', vectorizer),
    ('svd', NMF(60)),
    ('clf', KNeighborsClassifier(n_neighbors=7))
])

# %%
metrics_knc_nmf, errors_knc_nmf = eval_table(data['description_norm'], data['category_name'], knc_nmf)
metrics_knc_nmf
# Out:
#                             precision  precision_std  recall  recall_std  \
# Предложение услуг                0.52           0.06    0.57        0.06
# Ремонт и строительство           0.42           0.08    0.18        0.03
# Автомобили                       0.52           0.05    0.64        0.05
# Бытовая техника                  0.27           0.03    0.19        0.04
# Телефоны                         0.70           0.07    0.46        0.10
# Товары для детей и игрушки       0.54           0.06    0.31        0.05
# Детская одежда и обувь           0.46           0.02    0.59        0.02
# Квартиры                         0.92           0.03    0.80        0.04
# Мебель и интерьер                0.29           0.03    0.21        0.04
# Одежда, обувь, аксессуары        0.50           0.01    0.57        0.03
# mean                             0.51           0.04    0.45        0.05
#
#                               f1  f1_std
# Предложение услуг           0.54    0.05
# Ремонт и строительство      0.25    0.05
# Автомобили                  0.57    0.05
# Бытовая техника             0.22    0.03
# Телефоны                    0.55    0.09
# Товары для детей и игрушки  0.39    0.05
# Детская одежда и обувь      0.52    0.02
# Квартиры                    0.85    0.03
# Мебель и интерьер           0.24    0.03
# Одежда, обувь, аксессуары   0.53    0.02
# mean                        0.47    0.04

# %%
# SVD
knc_svd = Pipeline([
    ('bow', vectorizer),
    ('svd', TruncatedSVD(500)),
    ('clf', KNeighborsClassifier(n_neighbors=7))
])

# %%
metrics_knc_svd, errors_knc_svd = eval_table(data['description_norm'], data['category_name'], knc_svd)
metrics_knc_svd
# Out:
#                             precision  precision_std  recall  recall_std  \
# Предложение услуг                0.70           0.05    0.51        0.04
# Ремонт и строительство           0.40           0.08    0.21        0.06
# Автомобили                       0.52           0.04    0.63        0.03
# Бытовая техника                  0.42           0.06    0.29        0.05
# Телефоны                         0.72           0.05    0.37        0.03
# Товары для детей и игрушки       0.60           0.06    0.30        0.05
# Детская одежда и обувь           0.48           0.01    0.68        0.02
# Квартиры                         0.94           0.04    0.78        0.03
# Мебель и интерьер                0.44           0.04    0.29        0.04
# Одежда, обувь, аксессуары        0.51           0.02    0.61        0.02
# mean                             0.57           0.04    0.47        0.04
#
#                               f1  f1_std
# Предложение услуг           0.59    0.04
# Ремонт и строительство      0.28    0.06
# Автомобили                  0.57    0.02
# Бытовая техника             0.35    0.05
# Телефоны                    0.49    0.02
# Товары для детей и игрушки  0.40    0.05
# Детская одежда и обувь      0.57    0.01
# Квартиры                    0.85    0.03
# Мебель и интерьер           0.35    0.04
# Одежда, обувь, аксессуары   0.56    0.02
# mean                        0.50    0.03

# %% [markdown]
# __RandomForestClassifier__

# %%
# NMF
rfc_nmf = Pipeline([
    ('bow', vectorizer),
    ('svd', NMF(60)),
    ('clf', RandomForestClassifier(n_estimators=100, max_depth=10))
])

# %%
metrics_rfc_nmf, errors_rfc_nmf = eval_table(data['description_norm'], data['category_name'], rfc_nmf)
metrics_rfc_nmf
# Out:
#                             precision  precision_std  recall  recall_std  \
# Предложение услуг                0.70           0.05    0.58        0.02
# Ремонт и строительство           0.66           0.05    0.23        0.05
# Автомобили                       0.81           0.06    0.77        0.04
# Бытовая техника                  1.00           0.00    0.04        0.02
# Телефоны                         0.81           0.05    0.65        0.05
# Товары для детей и игрушки       0.81           0.05    0.44        0.03
# Детская одежда и обувь           0.66           0.03    0.68        0.03
# Квартиры                         0.93           0.02    0.94        0.02
# Мебель и интерьер                0.64           0.07    0.27        0.07
# Одежда, обувь, аксессуары        0.49           0.01    0.79        0.02
# mean                             0.75           0.04    0.54        0.04
#
#                               f1  f1_std
# Предложение услуг           0.63    0.02
# Ремонт и строительство      0.34    0.05
# Автомобили                  0.79    0.03
# Бытовая техника             0.08    0.04
# Телефоны                    0.72    0.04
# Товары для детей и игрушки  0.57    0.03
# Детская одежда и обувь      0.67    0.02
# Квартиры                    0.93    0.01
# Мебель и интерьер           0.38    0.08
# Одежда, обувь, аксессуары   0.60    0.00
# mean                        0.57    0.03

# %%
# SVD
rfc_svd = Pipeline([
    ('bow', vectorizer),
    ('svd', TruncatedSVD(500)),
    ('clf', RandomForestClassifier(n_estimators=100, max_depth=10))
])

# %%
metrics_rfc_svd, errors_rfc_svd = eval_table(data['description_norm'], data['category_name'], rfc_svd)
metrics_rfc_svd
# Out:
#                             precision  precision_std  recall  recall_std  \
# Предложение услуг                0.77           0.02    0.51        0.03
# Ремонт и строительство           0.66           0.18    0.09        0.03
# Автомобили                       0.90           0.04    0.59        0.02
# Бытовая техника                  0.76           0.16    0.05        0.02
# Телефоны                         0.93           0.06    0.42        0.07
# Товары для детей и игрушки       0.82           0.07    0.23        0.04
# Детская одежда и обувь           0.47           0.02    0.73        0.02
# Квартиры                         0.87           0.02    0.92        0.02
# Мебель и интерьер                0.88           0.16    0.04        0.02
# Одежда, обувь, аксессуары        0.49           0.01    0.76        0.01
# mean                             0.76           0.07    0.43        0.03
#
#                               f1  f1_std
# Предложение услуг           0.61    0.01
# Ремонт и строительство      0.16    0.06
# Автомобили                  0.71    0.02
# Бытовая техника             0.10    0.03
# Телефоны                    0.58    0.08
# Товары для детей и игрушки  0.36    0.05
# Детская одежда и обувь      0.57    0.02
# Квартиры                    0.89    0.02
# Мебель и интерьер           0.08    0.04
# Одежда, обувь, аксессуары   0.59    0.01
# mean                        0.46    0.03

# %% [markdown]
# __ExtraTreesClassifier__

# %%
# NMF
etc_nmf = Pipeline([
    ('bow', vectorizer),
    ('svd', NMF(60)),
    ('clf', ExtraTreesClassifier(random_state=0))
])

# %%
metrics_etc_nmf, errors_etc_nmf = eval_table(data['description_norm'], data['category_name'], etc_nmf)
metrics_etc_nmf
# Out:
#                             precision  precision_std  recall  recall_std  \
# Предложение услуг                0.71           0.05    0.77        0.03
# Ремонт и строительство           0.60           0.06    0.39        0.08
# Автомобили                       0.78           0.01    0.87        0.04
# Бытовая техника                  0.53           0.09    0.22        0.04
# Телефоны                         0.82           0.03    0.73        0.03
# Товары для детей и игрушки       0.68           0.04    0.53        0.05
# Детская одежда и обувь           0.63           0.02    0.73        0.01
# Квартиры                         0.92           0.01    0.96        0.02
# Мебель и интерьер                0.62           0.06    0.39        0.05
# Одежда, обувь, аксессуары        0.63           0.02    0.71        0.02
# mean                             0.69           0.04    0.63        0.04
#
#                               f1  f1_std
# Предложение услуг           0.74    0.03
# Ремонт и строительство      0.47    0.08
# Автомобили                  0.82    0.02
# Бытовая техника             0.31    0.05
# Телефоны                    0.77    0.02
# Товары для детей и игрушки  0.59    0.04
# Детская одежда и обувь      0.68    0.01
# Квартиры                    0.94    0.01
# Мебель и интерьер           0.48    0.05
# Одежда, обувь, аксессуары   0.67    0.01
# mean                        0.65    0.03

# %%
# SVD
etc_svd = Pipeline([
    ('bow', vectorizer),
    ('svd', TruncatedSVD(500)),
    ('clf', ExtraTreesClassifier(random_state=0))
])

# %%
metrics_etc_svd, errors_etc_svd = eval_table(data['description_norm'], data['category_name'], etc_svd)
metrics_etc_svd
# Out:
#                             precision  precision_std  recall  recall_std  \
# Предложение услуг                0.85           0.04    0.27        0.03
# Ремонт и строительство           0.58           0.04    0.09        0.01
# Автомобили                       0.78           0.07    0.46        0.04
# Бытовая техника                  0.64           0.13    0.14        0.02
# Телефоны                         0.88           0.05    0.36        0.05
# Товары для детей и игрушки       0.67           0.04    0.19        0.03
# Детская одежда и обувь           0.46           0.01    0.74        0.05
# Квартиры                         0.75           0.03    0.81        0.06
# Мебель и интерьер                0.71           0.05    0.15        0.02
# Одежда, обувь, аксессуары        0.48           0.02    0.73        0.01
# mean                             0.68           0.05    0.39        0.03
#
#                               f1  f1_std
# Предложение услуг           0.41    0.04
# Ремонт и строительство      0.16    0.02
# Автомобили                  0.58    0.04
# Бытовая техника             0.22    0.04
# Телефоны                    0.51    0.05
# Товары для детей и игрушки  0.29    0.04
# Детская одежда и обувь      0.57    0.02
# Квартиры                    0.77    0.04
# Мебель и интерьер           0.24    0.03
# Одежда, обувь, аксессуары   0.58    0.01
# mean                        0.43    0.03

# %%
all_metrics = [metrics_sgdc_nmf, metrics_sgdc_svd, metrics_knc_nmf, metrics_knc_svd, 
                 metrics_rfc_nmf, metrics_rfc_svd, metrics_etc_nmf, metrics_etc_svd]

all_names = ['SGDClassifier_NMF','SGDClassifier_SVD', 'KNeighborsClassifier_NMF', 'KNeighborsClassifier_SVD',
                'RandomForestClassifier_NMF', 'RandomForestClassifier_SVD', 'ExtraTreesClassifier_NMF', 'ExtraTreesClassifier_SVD']

# %%
metrics_comparison = pd.DataFrame()
for m in all_metrics:
    metrics_comparison = metrics_comparison.append(m.loc['mean'])
metrics_comparison.index=pd.Series(all_names)
display(metrics_comparison)
# Out:
#                             precision  precision_std  recall  recall_std  \
# SGDClassifier_NMF                0.64           0.11    0.54        0.13
# SGDClassifier_SVD                0.75           0.05    0.70        0.04
# KNeighborsClassifier_NMF         0.51           0.04    0.45        0.05
# KNeighborsClassifier_SVD         0.57           0.04    0.47        0.04
# RandomForestClassifier_NMF       0.75           0.04    0.54        0.04
# RandomForestClassifier_SVD       0.76           0.07    0.43        0.03
# ExtraTreesClassifier_NMF         0.69           0.04    0.63        0.04
# ExtraTreesClassifier_SVD         0.68           0.05    0.39        0.03
#
#                               f1  f1_std
# SGDClassifier_NMF           0.54    0.07
# SGDClassifier_SVD           0.72    0.03
# KNeighborsClassifier_NMF    0.47    0.04
# KNeighborsClassifier_SVD    0.50    0.03
# RandomForestClassifier_NMF  0.57    0.03
# RandomForestClassifier_SVD  0.46    0.03
# ExtraTreesClassifier_NMF    0.65    0.03
# ExtraTreesClassifier_SVD    0.43    0.03

# %% [markdown]
# __Судя по результатам, наилучшее сочетание - это SGDClassifier и SVD.__

# %% [markdown]
# ### Задание № 2 (6 баллов)

# %%
def metrics(corpus, texts, dictinary, lda):
    print(f'Perplexity: {np.exp2(-lda.log_perplexity(corpus))}')
    
    topics = []
    for topic_id, topic in lda.show_topics(num_topics=100, formatted=False):
        topic = [word for word, _ in topic]
        topics.append(topic)
        
    coherence_model_lda = gensim.models.CoherenceModel(topics=topics, 
                                                   texts=[text.split() for text in texts_norm], 
                                                   dictionary=dictinary, coherence='c_v')
    
    print(f'Coherence: {coherence_model_lda.get_coherence()}')

# %% [markdown]
# __Модель без нграмм и tfidf__

# %%
texts = open('wiki_data.txt', encoding='utf-8').read().splitlines()[:5000]
texts_norm = ([normalize(text) for text in texts])

# %%
dictinary_1 = gensim.corpora.Dictionary((text.split() for text in texts_norm))

# %%
dictinary_1.filter_extremes(no_above=0.1, no_below=10)
dictinary_1.compactify()

# %%
corpus_1 = [dictinary_1.doc2bow(text.split()) for text in texts_norm]

# %%
lda_1 = gensim.models.LdaMulticore(corpus_1, 
                                 100, # колиество тем
                                 alpha='asymmetric',
                                 id2word=dictinary_1, 
                                 passes=10)

# %%
metrics_1 = metrics(corpus_1, texts_norm, dictinary_1, lda_1)
print(metrics_1)
# Out:
# Perplexity: 337.5593909373696
# Coherence: 0.51777926960439
# None

# %% [markdown]
# __Модель с нграммами__

# %%
ngrams_1 = [text.split() for text in texts_norm]
ph = gensim.models.Phrases(ngrams_1, scoring='npmi', threshold=0.4) # threshold можно подбирать
p = gensim.models.phrases.Phraser(ph)
ngrammed_texts = p[ngrams_1]

# %% [markdown]
# Проверка

# %%
[text[:15] for text in ngrammed_texts[:1]]
# Out:
# [['новостройка',
#   'нижегородский_область',
#   'новостро́йка',
#   '—',
#   'сельский',
#   'посёлок',
#   'в',
#   'дивеевский_район',
#   'нижегородский_область',
#   'входить',
#   'в',
#   'состав_сатисский',
#   'сельсовет',
#   'посёлок',
#   'расположить']]

# %%
dictinary_2 = gensim.corpora.Dictionary((ngrammed_texts))

# %%
dictinary_2.filter_extremes(no_above=0.1, no_below=10)
dictinary_2.compactify()

# %%
corpus_2 = [dictinary_2.doc2bow(text) for text in ngrammed_texts]

# %%
lda_2 = gensim.models.LdaMulticore(corpus_2, 
                                 100, # число тем
                                 alpha='asymmetric',
                                 id2word=dictinary_2, 
                                 passes=10)

# %%
metrics_2 = metrics(corpus_2, ngrammed_texts, dictinary_2, lda_2)
print(metrics_2)
# Out:
# Perplexity: 430.19540812345906
# Coherence: nan
# None

# %% [markdown]
# __Модель с tfidf__

# %%
texts_ = open('wiki_data.txt', encoding='utf-8').read().splitlines()[:5000]
texts_norm = ([normalize(text) for text in texts_])

# %%
dictinary_3 = gensim.corpora.Dictionary((text.split() for text in texts_norm))

# %%
dictinary_3.filter_extremes(no_above=0.1, no_below=10)
dictinary_3.compactify()

# %%
corpus_3 = [dictinary_3.doc2bow(text.split()) for text in texts_norm]

# %%
tfidf = gensim.models.TfidfModel(corpus_3)
corpus_3 = [tfidf[text] for text in corpus_3]

# %%
lda_3 = gensim.models.LdaMulticore(corpus_3, 
                                 100, # число тем
                                 alpha='asymmetric',
                                 id2word=dictinary_3, 
                                 passes=10)

# %%
metrics_3 = metrics(corpus_3, texts_norm, dictinary_3, lda_3)
print(metrics_3)
# Out:
# Perplexity: 20364.41663545552
# Coherence: 0.4055424811098349
# None

# %% [markdown]
# __Модель с нграммами и tfidf__

# %%
tfidf = gensim.models.TfidfModel(corpus_2)
corpus_4 = [tfidf[text] for text in corpus_2]

# %%
lda_4 = gensim.models.LdaMulticore(corpus_4, 
                                 100, # число тем
                                 alpha='asymmetric',
                                 id2word=dictinary_2, 
                                 passes=2)

# %%
metrics_4 = metrics(corpus_4, texts_norm, dictinary_2, lda_4)
print(metrics_4)
# Out:
# Perplexity: 271051.81226070283
# Coherence: nan
# None

# %% [markdown]
# __Лучшей оказалась самая первая модель, как в семинаре. Почему-то для нграмных моделей Coherence выдает nan. К сожалению, с этом я разобраться не смогла.__

# %%
lda_1.print_topics()
# Out:
# [(99,
#   '0.020*"оркестр" + 0.014*"десант" + 0.013*"музыка" + 0.011*"инструмент" + 0.008*"высадка" + 0.007*"играть" + 0.006*"зал" + 0.005*"морской" + 0.005*"здание" + 0.005*"рог"'),
#  (98,
#   '0.057*"река" + 0.053*"км" + 0.029*"берег" + 0.026*"сельский" + 0.024*"дорога" + 0.021*"совет" + 0.021*"озеро" + 0.019*"харьковский" + 0.018*"расстояние" + 0.017*"станция"'),
#  (97,
#   '0.030*"канада" + 0.012*"ибн" + 0.009*"герб" + 0.008*"’" + 0.008*"список" + 0.007*"польский" + 0.006*"качество" + 0.006*"польша" + 0.006*"национальный" + 0.006*"уровень"'),
#  (96,
#   '0.077*"деревня" + 0.029*"сельсовет" + 0.013*"коммуна" + 0.010*"п" + 0.009*"литва" + 0.009*"двор" + 0.008*"житель" + 0.007*"данные" + 0.007*"дом" + 0.007*"губерния"'),
#  (94,
#   '0.017*"серия" + 0.016*"брат" + 0.013*"озеро" + 0.012*"грязь" + 0.011*"книга" + 0.011*"джейн" + 0.009*"друг" + 0.009*"произведение" + 0.008*"знание" + 0.007*"джо"'),
#  (95,
#   '0.019*"команда" + 0.017*"сезон" + 0.013*"f" + 0.012*"ferrari" + 0.010*"болид" + 0.009*"брянский" + 0.009*"чемпионат" + 0.009*"мир" + 0.009*"луис" + 0.008*"конструктор"'),
#  (93,
#   '0.052*"сельсовет" + 0.042*"поселение" + 0.025*"сельский" + 0.025*"посёлок" + 0.022*"деревня" + 0.016*"муниципальный" + 0.014*"пункт" + 0.014*"курский" + 0.013*"образование" + 0.009*"14"'),
#  (92,
#   '0.043*"cryptocephalus" + 0.033*"подсемейство" + 0.024*"европа" + 0.018*"поселковый" + 0.017*"распространить" + 0.015*"латвия" + 0.014*"встречаться" + 0.012*"ликвидировать" + 0.011*"северный" + 0.011*"франция"'),
#  (91,
#   '0.036*"де" + 0.034*"граф" + 0.025*"сын" + 0.024*"i" + 0.023*"король" + 0.021*"ii" + 0.016*"графство" + 0.014*"герцог" + 0.014*"дочь" + 0.012*"смерть"'),
#  (89,
#   '0.021*"герб" + 0.011*"щит" + 0.010*"губерния" + 0.009*"рсдрп" + 0.007*"москва" + 0.006*"киев" + 0.006*"золотой" + 0.006*"река" + 0.006*"московский" + 0.006*"нижегородский"'),
#  (9,
#   '0.014*"раунд" + 0.009*"бой" + 0.007*"налог" + 0.006*"месторождение" + 0.006*"россия" + 0.006*"день" + 0.005*"организм" + 0.005*"налоговый" + 0.005*"социальный" + 0.004*"доход"'),
#  (8,
#   '0.009*"км" + 0.007*"построить" + 0.007*"поселение" + 0.007*"дом" + 0.006*"округ" + 0.005*"иметься" + 0.005*"фабрика" + 0.005*"сельский" + 0.005*"здание" + 0.005*"житель"'),
#  (7,
#   '0.009*"партия" + 0.008*"университет" + 0.008*"член" + 0.006*"институт" + 0.006*"россия" + 0.006*"президент" + 0.006*"государственный" + 0.006*"политический" + 0.005*"общество" + 0.005*"правительство"'),
#  (6,
#   '0.016*"ван" + 0.008*"провинция" + 0.006*"китай" + 0.006*"вместе" + 0.005*"игла" + 0.004*"альберт" + 0.004*"обычно" + 0.004*"можно" + 0.004*"доска" + 0.004*"вода"'),
#  (5,
#   '0.034*"суд" + 0.026*"попельнянский" + 0.015*"зимний" + 0.014*"верховный" + 0.013*"2002" + 0.011*"сша" + 0.010*"4137" + 0.008*"судья" + 0.008*"судебный" + 0.008*"бобслей"'),
#  (4,
#   '0.029*"тыс" + 0.017*"министр" + 0.012*"северный" + 0.010*"квинта" + 0.009*"численность" + 0.009*"кабинет" + 0.008*"н" + 0.008*"регион" + 0.008*"э" + 0.007*"ирландия"'),
#  (3,
#   '0.010*"ким" + 0.009*"мир" + 0.007*"2010" + 0.007*"сша" + 0.006*"премия" + 0.006*"ребёнок" + 0.006*"фильм" + 0.005*"ли" + 0.004*"школа" + 0.004*"бал"'),
#  (2,
#   '0.016*"россия" + 0.013*"въезд" + 0.011*"фамилия" + 0.010*"гражданин" + 0.008*"паспорт" + 0.008*"власть" + 0.007*"режим" + 0.007*"посещение" + 0.006*"республика" + 0.006*"рф"'),
#  (1,
#   '0.121*"житомирский" + 0.054*"почтовый" + 0.051*"км²" + 0.050*"индекс" + 0.050*"телефонный" + 0.050*"р-н" + 0.043*"ул" + 0.040*"коатуа" + 0.022*"радомышльский" + 0.019*"романовский"'),
#  (0,
#   '0.074*"летний" + 0.036*"спортсмен" + 0.033*"сборная" + 0.031*"ни" + 0.031*"женщина" + 0.027*"зимний" + 0.017*"соревнование" + 0.015*"бронзовый" + 0.013*"серебряный" + 0.011*"мужчина"')]

# %% [markdown]
# __Самая красивая тема:__ (96,
#   '0.077*"деревня" + 0.029*"сельсовет" + 0.013*"коммуна" + 0.010*"п" + 0.009*"литва" + 0.009*"двор" + 0.008*"житель" + 0.007*"данные" + 0.007*"дом" + 0.007*"губерния"')

# %%
lda_2.print_topics()
# Out:
# [(99,
#   '0.023*"иордания" + 0.016*"израиль" + 0.008*"епархия" + 0.006*"организация" + 0.006*"животное" + 0.006*"якутский" + 0.006*"израильский" + 0.006*"сентябрь" + 0.005*"лесной" + 0.005*"сторона"'),
#  (98,
#   '0.025*"звезда" + 0.015*"кладбище" + 0.008*"система" + 0.007*"эстония" + 0.007*"иран" + 0.006*"солнце" + 0.006*"мемориал" + 0.006*"колхоз" + 0.005*"b" + 0.005*"участок"'),
#  (97,
#   '0.011*"мочь" + 0.009*"парк" + 0.007*"авиакомпания" + 0.007*"каждый" + 0.007*"цилиндр" + 0.006*"система" + 0.006*"проект" + 0.005*"microsoft" + 0.005*"изображение" + 0.004*"версия"'),
#  (95,
#   '0.013*"растение" + 0.010*"земля" + 0.009*"напряжение" + 0.009*"одесса" + 0.008*"вода" + 0.008*"одесский" + 0.008*"антенна" + 0.007*"писатель" + 0.005*"обычно" + 0.005*"воздух"'),
#  (96,
#   '0.051*"клуб" + 0.030*"команда" + 0.028*"матч" + 0.012*"гол" + 0.012*"перейти" + 0.011*"чемпионат" + 0.011*"игрок" + 0.011*"провести" + 0.010*"сезон" + 0.010*"игра"'),
#  (94,
#   '0.021*"подводный_лодка" + 0.010*"село" + 0.010*"флот" + 0.009*"корабль" + 0.007*"манёвр" + 0.007*"проект" + 0.006*"лодка" + 0.005*"учение" + 0.005*"крейсер" + 0.005*"партия"'),
#  (93,
#   '0.014*"румынский" + 0.012*"матрица" + 0.011*"баня" + 0.010*"румыния" + 0.007*"бретань" + 0.007*"линейный" + 0.007*"то" + 0.006*"пара" + 0.006*"эда" + 0.006*"включить"'),
#  (92,
#   '0.015*"группа" + 0.010*"россия" + 0.008*"театр" + 0.007*"музыкальный" + 0.006*"музыка" + 0.006*"российский" + 0.005*"программа" + 0.004*"фестиваль" + 0.004*"проект" + 0.004*"сергей"'),
#  (91,
#   '0.081*"остров" + 0.011*"август" + 0.009*"россия" + 0.009*"эскадра" + 0.007*"северный" + 0.007*"июль" + 0.006*"генерал-лейтенант" + 0.005*"строительный" + 0.005*"генерал-майор" + 0.005*"километр"'),
#  (90,
#   '0.045*"китай" + 0.024*"япония" + 0.017*"листоед" + 0.013*"из_подсемейство" + 0.011*"японский" + 0.010*"кормовой_растение" + 0.010*"трактат" + 0.009*"лист" + 0.009*"встречаться" + 0.009*"сибирь"'),
#  (9,
#   '0.055*"игра" + 0.012*"игрок" + 0.009*"уровень" + 0.009*"император" + 0.007*"враг" + 0.007*"мочь" + 0.005*"компьютерный_игра" + 0.005*"игровой" + 0.005*"персонаж" + 0.005*"можно"'),
#  (8,
#   '0.012*"бен" + 0.010*"список" + 0.009*"компания" + 0.008*"стадион" + 0.008*"чёрный" + 0.007*"группа" + 0.007*"остров" + 0.006*"храм" + 0.006*"серия" + 0.005*"r"'),
#  (7,
#   '0.010*"фильм" + 0.007*"я" + 0.005*"чтобы" + 0.005*"себя" + 0.005*"жизнь" + 0.004*"хороший" + 0.004*"мир" + 0.003*"день" + 0.003*"дом" + 0.003*"роман"'),
#  (6,
#   '0.008*"книга" + 0.004*"мочь" + 0.003*"себя" + 0.003*"жизнь" + 0.003*"…" + 0.003*"ребёнок" + 0.003*"слово" + 0.003*"рассказ" + 0.003*"между" + 0.003*"вопрос"'),
#  (5,
#   '0.013*"версия" + 0.007*"выпуск" + 0.006*"убить" + 0.006*"убийца" + 0.005*"машина" + 0.005*"завод" + 0.005*"л" + 0.004*"2005_год" + 0.004*"автомобиль" + 0.004*"поддержка"'),
#  (4,
#   '0.017*"театр" + 0.007*"император" + 0.007*"китайский" + 0.005*"украинский" + 0.004*"знание" + 0.004*"китай" + 0.004*"николаевский" + 0.004*"формат" + 0.003*"деятельность" + 0.003*"сцена"'),
#  (3,
#   '0.018*"сын" + 0.014*"король" + 0.011*"князь" + 0.008*"дочь" + 0.007*"жена" + 0.006*"брат" + 0.006*"герцог" + 0.005*"брак" + 0.005*"владение" + 0.005*"род"'),
#  (2,
#   '0.016*"ружинский_район" + 0.016*"олевскома_район" + 0.015*"—_4135" + 0.014*"олевский_р-н" + 0.013*"ружинский_р-н" + 0.011*"—_4138" + 0.010*"крейсер" + 0.008*"корабль" + 0.008*"клиент" + 0.007*"житомирский_область"'),
#  (1,
#   '0.038*"за_свой" + 0.033*"летний_олимпийский" + 0.031*"на_летний" + 0.031*"олимпийский_игра" + 0.029*"не_завоевать" + 0.029*"ни_один" + 0.028*"история_но" + 0.024*"медаль_сборная" + 0.024*"женщина" + 0.023*"страна_представлять"'),
#  (0,
#   '0.077*"житомирский_область" + 0.056*"село" + 0.041*"население_по" + 0.041*"перепись_2001" + 0.041*"год_составлять" + 0.034*"на_украина" + 0.033*"индекс_—" + 0.033*"человек_почтовый" + 0.031*"код_коатуа" + 0.031*"км²"')]

# %% [markdown]
# __Самая красивая тема:__ (9,
#   '0.055*"игра" + 0.012*"игрок" + 0.009*"уровень" + 0.009*"император" + 0.007*"враг" + 0.007*"мочь" + 0.005*"компьютерный_игра" + 0.005*"игровой" + 0.005*"персонаж" + 0.005*"можно"')

# %%
lda_3.print_topics()
# Out:
# [(98,
#   '0.000*"просвещение" + 0.000*"издательство" + 0.000*"компания" + 0.000*"учебник" + 0.000*"матч" + 0.000*"забить" + 0.000*"цска" + 0.000*"гол" + 0.000*"президент" + 0.000*"co"'),
#  (99,
#   '0.000*"портрет" + 0.000*"икона" + 0.000*"комната" + 0.000*"санкт-петербург" + 0.000*"александр" + 0.000*"авторский" + 0.000*"мастер" + 0.000*"александрович" + 0.000*"казанский" + 0.000*"техника"'),
#  (97,
#   '0.005*"подбор" + 0.001*"тим" + 0.000*"подразумеваться" + 0.000*"ричард" + 0.000*"ирландия" + 0.000*"сезон" + 0.000*"генрих" + 0.000*"севастополь" + 0.000*"де" + 0.000*"очко"'),
#  (96,
#   '0.000*"билет" + 0.000*"посёлок" + 0.000*"совхоз" + 0.000*"портрет" + 0.000*"житель" + 0.000*"замок" + 0.000*"печать" + 0.000*"полевой" + 0.000*"усадьба" + 0.000*"км"'),
#  (95,
#   '0.001*"патрик" + 0.000*"животное" + 0.000*"смотреть" + 0.000*"ян" + 0.000*"рига" + 0.000*"святой" + 0.000*"король" + 0.000*"как-то" + 0.000*"эссе" + 0.000*"построить"'),
#  (94,
#   '0.004*"крепиться" + 0.003*"единичный" + 0.001*"белок" + 0.000*"деление" + 0.000*"клетка" + 0.000*"обозначение" + 0.000*"взаимодействовать" + 0.000*"родительский" + 0.000*"эволюция" + 0.000*"млекопитающее"'),
#  (93,
#   '0.000*"блестящий" + 0.000*"суд" + 0.000*"смотреть" + 0.000*"ствол" + 0.000*"мм" + 0.000*"штат" + 0.000*"1986" + 0.000*"эвкалипт" + 0.000*"сидячий" + 0.000*"диаметр"'),
#  (91,
#   '0.000*"университет" + 0.000*"ректор" + 0.000*"математический" + 0.000*"квартира" + 0.000*"ломоносов" + 0.000*"ч" + 0.000*"государственный" + 0.000*"факультет" + 0.000*"астрономия" + 0.000*"вуз"'),
#  (92,
#   '0.000*"продажа" + 0.000*"противоречить" + 0.000*"пребывание" + 0.000*"признанный" + 0.000*"принудительный" + 0.000*"прогресс" + 0.000*"поправка" + 0.000*"противоречие" + 0.000*"смертный" + 0.000*"рассмотрение"'),
#  (90,
#   '0.000*"екатеринбург" + 0.000*"премия" + 0.000*"фантастика" + 0.000*"рассказ" + 0.000*"книга" + 0.000*"уральский" + 0.000*"государство" + 0.000*"фестиваль" + 0.000*"литература" + 0.000*"писатель"'),
#  (9,
#   '0.013*"героиня" + 0.001*"клетка" + 0.001*"мозг" + 0.001*"регистр" + 0.000*"остров" + 0.000*"цилиндр" + 0.000*"линия" + 0.000*"навык" + 0.000*"убийца" + 0.000*"убийство"'),
#  (8,
#   '0.021*"кошка" + 0.019*"алексей" + 0.011*"плата" + 0.007*"математик" + 0.007*"танцовщица" + 0.006*"джованни" + 0.005*"голод" + 0.004*"цветовой" + 0.003*"переработка" + 0.003*"владислав"'),
#  (7,
#   '0.076*"перу" + 0.029*"термин" + 0.018*"теорема" + 0.018*"лыжник" + 0.012*"идеальный" + 0.005*"уголь" + 0.000*"тон" + 0.000*"ссср" + 0.000*"прибор" + 0.000*"сидней"'),
#  (6,
#   '0.018*"тайвань" + 0.017*"тайбэя" + 0.017*"чэнь" + 0.014*"цепь" + 0.011*"голый" + 0.008*"собака" + 0.006*"банда" + 0.005*"архангел" + 0.005*"остров" + 0.004*"швед"'),
#  (5,
#   '0.076*"долгота" + 0.036*"океан" + 0.018*"гриб" + 0.016*"лукаш" + 0.015*"боксёр" + 0.009*"павел" + 0.007*"прозрачный" + 0.007*"эрнст" + 0.007*"кит" + 0.007*"устройство"'),
#  (4,
#   '0.157*"значение" + 0.035*"жуков" + 0.025*"семейство" + 0.020*"куба" + 0.020*"гвинея" + 0.019*"теннисный" + 0.019*"брисбен" + 0.015*"boys" + 0.014*"населять" + 0.010*"максим"'),
#  (3,
#   '0.023*"уругвай" + 0.022*"гуго" + 0.015*"суперкубок" + 0.015*"бургундия" + 0.014*"рыжий" + 0.012*"бен" + 0.012*"эда" + 0.011*"1770" + 0.009*"сицилия" + 0.009*"канцлер"'),
#  (2,
#   '0.051*"люксембург" + 0.030*"f" + 0.026*"лихтенштейн" + 0.023*"мехико" + 0.022*"означать" + 0.021*"мексика" + 0.021*"агава" + 0.020*"малайзия" + 0.017*"ботсвана" + 0.017*"белок"'),
#  (1,
#   '0.082*"житомирский" + 0.034*"р-н" + 0.034*"телефонный" + 0.034*"почтовый" + 0.033*"индекс" + 0.032*"км²" + 0.032*"коатуа" + 0.029*"ул" + 0.026*"радомышльский" + 0.021*"романовский"'),
#  (0,
#   '0.004*"летний" + 0.002*"зимний" + 0.002*"остров" + 0.002*"сборная" + 0.002*"ни" + 0.002*"км" + 0.002*"фильм" + 0.002*"спортсмен" + 0.002*"женщина" + 0.002*"клуб"')]

# %% [markdown]
# __Самая красивая тема:__ (1,
#   '0.082*"житомирский" + 0.034*"р-н" + 0.034*"телефонный" + 0.034*"почтовый" + 0.033*"индекс" + 0.032*"км²" + 0.032*"коатуа" + 0.029*"ул" + 0.026*"радомышльский" + 0.021*"романовский"'),

# %%
lda_4.print_topics()
# Out:
# [(99,
#   '0.004*"стамбул" + 0.004*"альберт" + 0.004*"герб" + 0.003*"украшение" + 0.002*"провинциальный" + 0.002*"н_э" + 0.002*"символизировать" + 0.002*"драгоценный_камень" + 0.002*"пересечь" + 0.002*"изогнутый"'),
#  (98,
#   '0.006*"волга" + 0.006*"марк" + 0.004*"стр" + 0.003*"станица" + 0.002*"соревнование" + 0.002*"казак" + 0.002*"деревня" + 0.002*"поляк" + 0.002*"команда" + 0.002*"выпуск"'),
#  (96,
#   '0.002*"жалоба" + 0.001*"чемпионат_мир" + 0.001*"среди_юниор" + 0.001*"судья" + 0.001*"монгольский" + 0.001*"суд" + 0.001*"рекорд" + 0.001*"быть_назначить" + 0.001*"завоевать" + 0.001*"должность"'),
#  (97,
#   '0.019*"белокалитвинский_район" + 0.008*"алла_пугачёв" + 0.003*"прогноз" + 0.003*"песня" + 0.002*"карта" + 0.002*"дом" + 0.002*"писатель" + 0.001*"округ" + 0.001*"станица" + 0.001*"шторм"'),
#  (95,
#   '0.000*"расстояние_между" + 0.000*"сексуальный" + 0.000*"психический" + 0.000*"психологический" + 0.000*"раздел" + 0.000*"разделиться" + 0.000*"разрабатываться" + 0.000*"прозвучать" + 0.000*"самец" + 0.000*"соответствие"'),
#  (94,
#   '0.003*"завод" + 0.003*"установка" + 0.003*"переработка" + 0.003*"самолёт" + 0.002*"нефть" + 0.001*"село" + 0.001*"воронеж" + 0.001*"газовый" + 0.001*"штурм" + 0.001*"израильский"'),
#  (92,
#   '0.005*"икона" + 0.004*"одесский" + 0.003*"свердловск" + 0.002*"ярославский" + 0.002*"xiii_век" + 0.002*"одесса" + 0.002*"пётр" + 0.002*"эвакуация" + 0.002*"1300" + 0.001*"народный_артист"'),
#  (93,
#   '0.002*"полка" + 0.002*"противник" + 0.002*"самолёт" + 0.002*"батальон" + 0.001*"старший_лейтенант" + 0.001*"лётчик" + 0.001*"истребитель" + 0.001*"штаб" + 0.001*"командир" + 0.001*"бой"'),
#  (91,
#   '0.011*"плато" + 0.003*"облисполком" + 0.003*"первый_секретарь" + 0.002*"горный" + 0.002*"треста" + 0.002*"донецкий" + 0.002*"комбинат" + 0.002*"николаев" + 0.001*"обком" + 0.001*"индустриальный"'),
#  (89,
#   '0.002*"собака" + 0.002*"кэтрин" + 0.002*"фильм" + 0.001*"кошка" + 0.001*"мистер" + 0.001*"месть" + 0.001*"обнаруживать" + 0.001*"пёс" + 0.001*"агент" + 0.001*"миллион_доллар"'),
#  (9,
#   '0.004*"вагон" + 0.003*"тим" + 0.003*"вино" + 0.003*"фабрика" + 0.003*"команда" + 0.002*"цепь" + 0.002*"албания" + 0.002*"уездный_город" + 0.002*"томский" + 0.002*"святитель"'),
#  (8,
#   '0.005*"таджикистан" + 0.003*"танец" + 0.003*"епископ" + 0.003*"денис" + 0.002*"шина" + 0.002*"евгений" + 0.002*"налог" + 0.002*"саундтрек" + 0.002*"остров" + 0.002*"отречение"'),
#  (7,
#   '0.007*"пункт" + 0.004*"кошка" + 0.003*"оон" + 0.003*"павел" + 0.003*"наркотик" + 0.003*"цивилизация" + 0.002*"рен" + 0.002*"я" + 0.002*"глава_правительство" + 0.002*"песня"'),
#  (6,
#   '0.002*"университет" + 0.002*"коста-рика" + 0.002*"эда" + 0.002*"ул" + 0.002*"дмитрий" + 0.002*"знание" + 0.002*"махачкала" + 0.002*"израиль" + 0.001*"клуб" + 0.001*"утвердить_решение"'),
#  (5,
#   '0.005*"подсемейство" + 0.003*"пещера" + 0.002*"имаго" + 0.002*"лукаш" + 0.002*"мясо" + 0.002*"питаться" + 0.002*"зуб" + 0.002*"игра" + 0.002*"мультсериал" + 0.002*"лайнер"'),
#  (4,
#   '0.002*"крест" + 0.002*"герб" + 0.002*"1810" + 0.002*"комикс" + 0.002*"гитлер" + 0.002*"нижегородский_область" + 0.002*"шрифт" + 0.002*"римский_папа" + 0.002*"дубовый_лист" + 0.002*"долгота"'),
#  (3,
#   '0.004*"пункт" + 0.002*"яйцо" + 0.002*"личинка" + 0.002*"игра_1948" + 0.002*"латвия" + 0.002*"лондон_великобритания" + 0.002*"1948" + 0.002*"жуков" + 0.002*"матрица" + 0.002*"болид"'),
#  (2,
#   '0.009*"значение" + 0.005*"на_летний" + 0.005*"за_свой" + 0.004*"олимпийский_игра" + 0.004*"медаль_сборная" + 0.004*"летний_олимпийский" + 0.004*"спортсмен" + 0.002*"женщина" + 0.002*"игра_1952" + 0.002*"следующий_раунд"'),
#  (1,
#   '0.004*"клуб" + 0.003*"остров" + 0.002*"команда" + 0.002*"матч" + 0.002*"сезон" + 0.001*"длина" + 0.001*"распространить" + 0.001*"игра" + 0.001*"сборная" + 0.001*"по_футбол"'),
#  (0,
#   '0.005*"житомирский_область" + 0.003*"село" + 0.003*"население_по" + 0.003*"год_составлять" + 0.003*"перепись_2001" + 0.002*"на_украина" + 0.002*"индекс_—" + 0.002*"человек_почтовый" + 0.002*"км²" + 0.002*"телефонный_код"')]

# %% [markdown]
# __Самая красивая тема:__ (93,
#   '0.002*"полка" + 0.002*"противник" + 0.002*"самолёт" + 0.002*"батальон" + 0.001*"старший_лейтенант" + 0.001*"лётчик" + 0.001*"истребитель" + 0.001*"штаб" + 0.001*"командир" + 0.001*"бой"')
